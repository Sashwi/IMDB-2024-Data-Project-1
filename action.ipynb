# %%
# !pip install selenium
# !pip install pandas

# %%
from selenium import webdriver
import pandas as  pd
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


driver = webdriver.Chrome()
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31")
time.sleep(5)

driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=action")
time.sleep(5)

titles=[]
ratings=[]
votings=[]
durations=[]

movies_in_page=driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for list_of_movies in movies_in_page:
    try:
    
        title = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/div[1]/a/h3").text

        rating = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/span/div/span/span[1]").text

        voting = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/span/div/span/span[2]").text

        duration = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/div[2]/span[2]").text

        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)

    except Exception as e:
        print(f"An error occured : {e}")
        continue

df=pd.DataFrame({
    'Title' : titles,
    'Rating': ratings,
    'Voting': votings,
    'Duration': durations
     })

driver.quit()
df
# Out:
#                                                 Title Rating   Voting Duration
# 0                                         1. Twisters    6.5   (168K)    2h 2m
# 1                                     2. Gladiator II    6.5   (230K)   2h 28m
# 2                             3. Sonic the Hedgehog 3    6.9    (59K)   1h 50m
# 3                                4. Kraven the Hunter    5.5    (55K)    2h 7m
# 4                             5. Deadpool & Wolverine    7.6   (492K)    2h 8m
# 5                                        6. Civil War    7.0   (237K)   1h 49m
# 6                                   7. Dune: Part Two    8.5   (625K)   2h 46m
# 7            8. The Ministry of Ungentlemanly Warfare    6.8   (135K)    2h 2m
# 8                            9. Venom: The Last Dance    6.0   (117K)   1h 50m
# 9                                   10. The Beekeeper    6.3   (157K)   1h 45m
# 10                      11. The Count of Monte-Cristo    7.6    (34K)   2h 58m
# ...

# %%
from selenium import webdriver
import pandas as  pd
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=action")
time.sleep(5)

def click_more_option():
    try:
        more_button= driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(more_button).perform()

        more_button.click()
        time.sleep(3)

        return(True)
    
    except Exception as e:
        print("error in clicking 'more_button':", e)
        return False
        
while click_more_option():
      print("Clicked more_button")

print("All contents are loaded.")
# Out:
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# Clicked more_button
# error in clicking 'more_button': Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span"}
# ...

# %%
movies_in_page=driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

# %%
len(movies_in_page)
# Out:
# 1344

# %%
from selenium import webdriver
import pandas as  pd
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


#driver = webdriver.Chrome()
#driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31")
#time.sleep(5)

#driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=action")
#time.sleep(5)

titles=[]
ratings=[]
votings=[]
durations=[]

movies_in_page=driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for list_of_movies in movies_in_page:
    try:
    
        title = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/div[1]/a/h3").text

        rating = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/span/div/span/span[1]").text

        voting = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/span/div/span/span[2]").text

        duration = list_of_movies.find_element(By.XPATH,"./div/div/div/div[1]/div[2]/div[2]/span[2]").text

        titles.append(title)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)

    except Exception as e:
        print(f"An error occured : {e}")
        continue

df=pd.DataFrame({
    'Title' : titles,
    'Rating': ratings,
    'Voting': votings,
    'Duration': durations
     })

driver.quit()
df
# Out:
# An error occured : Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=135.0.7049.115); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6680BEFA5+77893]
# 	GetHandleVerifier [0x00007FF6680BF000+77984]
# 	(No symbol) [0x00007FF667E891BA]
# 	(No symbol) [0x00007FF667EDF16D]
# 	(No symbol) [0x00007FF667EDF41C]
# 	(No symbol) [0x00007FF667ED1B1C]
# 	(No symbol) [0x00007FF667F0716F]
# 	(No symbol) [0x00007FF667ED19E6]
# 	(No symbol) [0x00007FF667F07340]
# 	(No symbol) [0x00007FF667F2F07F]
# 	(No symbol) [0x00007FF667F06F03]
# 	(No symbol) [0x00007FF667ED0328]
# 	(No symbol) [0x00007FF667ED1093]
# 	GetHandleVerifier [0x00007FF668377B6D+2931725]
# 	GetHandleVerifier [0x00007FF668372132+2908626]
# 	GetHandleVerifier [0x00007FF6683900F3+3031443]
# ...

# %%
df.to_csv("imdb_2024_action_movies.csv", index=False)
print(" Data saved to imdb_2024_crime_movies.csv")
# Out:
#  Data saved to imdb_2024_crime_movies.csv

# %%
df
# Out:
#                                    Title Rating   Voting Duration
# 0                            1. Twisters    6.5   (168K)    2h 2m
# 1                        2. Gladiator II    6.5   (230K)   2h 28m
# 2                3. Sonic the Hedgehog 3    6.9    (59K)   1h 50m
# 3                   4. Kraven the Hunter    5.5    (55K)    2h 7m
# 4                5. Deadpool & Wolverine    7.6   (492K)    2h 8m
# ..                                   ...    ...      ...      ...
# 812                        1290. Gadha17    8.0     (11)   1h 30m
# 813            1307. Runnin' from Wolves    7.2     (10)   2h 13m
# 814                     1309. Bush Knife    7.0      (7)   1h 30m
# 815  1313. Whispers of the Imperial City    6.8     (53)   1h 30m
# 816                  1334. Jefa De Jefas    8.2      (9)   1h 22m
#
# [817 rows x 4 columns]
